# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report,accuracy_score

# %%
# Loading the data
df=pd.read_csv('diabetes2.csv')

# %%
#Defining features and target

x=df.drop(columns={'Outcome'})
y=df['Outcome']

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Define the logistic regression model
log_model = LogisticRegression()

# %%
# Set up the hyperparameters to tune

param_grid = [
    {'C': [0.01, 0.1, 1, 10, 100], 'solver': ['liblinear'], 'penalty': ['l1', 'l2'], 'max_iter': [100, 200, 300]},
    {'C': [0.01, 0.1, 1, 10, 100], 'solver': ['lbfgs'], 'penalty': ['l2'], 'max_iter': [100, 200, 300]},
    {'C': [0.01, 0.1, 1, 10, 100], 'solver': ['saga'], 'penalty': ['l1', 'l2', 'elasticnet', 'none'], 'max_iter': [100, 200, 300]}
]

# %%
clf = GridSearchCV(log_model,param_grid = param_grid, cv = 3, verbose=True,n_jobs=-1)
clf
# Out:
# GridSearchCV(cv=3, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid=[{'C': [0.01, 0.1, 1, 10, 100],
#                           'max_iter': [100, 200, 300], 'penalty': ['l1', 'l2'],
#                           'solver': ['liblinear']},
#                          {'C': [0.01, 0.1, 1, 10, 100],
#                           'max_iter': [100, 200, 300], 'penalty': ['l2'],
#                           'solver': ['lbfgs']},
#                          {'C': [0.01, 0.1, 1, 10, 100],
#                           'max_iter': [100, 200, 300],
#                           'penalty': ['l1', 'l2', 'elasticnet', 'none'],
#                           'solver': ['saga']}],
#              verbose=True)

# %%
best_clf = clf.fit(x,y)
best_clf.best_estimator_
# Out:
# Fitting 3 folds for each of 105 candidates, totalling 315 fits
# C:\Users\suryasu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 90 fits failed out of a total of 315.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\suryasu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
print(f'Accuracy - : {best_clf.score(x,y):.3f}')
# Out:
# Accuracy - : 0.783

# %%
# Print the best parameters and the best score
print("Best Parameters:", clf.best_params_)
print("Best Score:", clf.best_score_)
# Out:
# Best Parameters: {'C': 1, 'max_iter': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# Best Score: 0.7734375
