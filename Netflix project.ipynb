# %% [markdown]
#  Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Import ratings data

# %%
df=pd.read_csv('Ratings.txt',header=None, names=['Cust_Id', 'Rating'], usecols = [0,1])

# %%
df
# Out:
#           Cust_Id  Rating
# 0              1:     NaN
# 1         1488844     3.0
# 2          822109     5.0
# 3          885013     4.0
# 4           30878     4.0
# ...           ...     ...
# 24058258  2591364     2.0
# 24058259  1791000     2.0
# 24058260   512536     5.0
# 24058261   988963     3.0
# 24058262  1704416     3.0
#
# [24058263 rows x 2 columns]

# %% [markdown]
# checking for null values

# %%
df.isna().sum()
# Out:
# Cust_Id       0
# Rating     4499
# dtype: int64

# %% [markdown]
# separating customer id and movie id into different columns
# ---------

# %%
df=df.fillna(0)

df['movie_id']=df['Cust_Id'].where(df['Rating']==0)
 
df['movie_id']=df['movie_id'].fillna(method='ffill')

df['Rating']=df['Rating'].replace({0 : np.nan})

df=df.dropna()

# %%
df['movie_id']=df['movie_id'].str.replace(':','')

df['movie_id']=df['movie_id'].astype(int)

df
# Out:
#           Cust_Id  Rating  movie_id
# 1         1488844     3.0         1
# 2          822109     5.0         1
# 3          885013     4.0         1
# 4           30878     4.0         1
# 5          823519     3.0         1
# ...           ...     ...       ...
# 24058258  2591364     2.0      4499
# 24058259  1791000     2.0      4499
# 24058260   512536     5.0      4499
# 24058261   988963     3.0      4499
# 24058262  1704416     3.0      4499
#
# [24053764 rows x 3 columns]

# %% [markdown]
# Number of movies

# %%
df['movie_id'].nunique()
# Out:
# 4499

# %% [markdown]
# Number of customers

# %%
df['Cust_Id'].nunique()
# Out:
# 470758

# %% [markdown]
# Number of rating

# %%
df['Rating'].count()
# Out:
# 24053764

# %% [markdown]
# Merging two data sets
# ---------------

# %%
df_title=pd.read_csv('movies_list.csv')

# %%
df_title
# Out:
#        movieId                               title              genres
# 0            1                    Toy Story (1995)           Adventure
# 1            2                      Jumanji (1995)           Adventure
# 2            3             Grumpier Old Men (1995)              Comedy
# 3            4            Waiting to Exhale (1995)              Comedy
# 4            5  Father of the Bride Part II (1995)              Comedy
# ...        ...                                 ...                 ...
# 27273   131254        Kein Bund für's Leben (2007)              Comedy
# 27274   131256       Feuer, Eis & Dosenbier (2002)              Comedy
# 27275   131258                  The Pirates (2014)           Adventure
# 27276   131260                 Rentun Ruusu (2001)  (no genres listed)
# 27277   131262                    Innocence (2014)           Adventure
#
# [27278 rows x 3 columns]

# %%
df=df.merge(df_title,how='left',left_on='movie_id',right_on='movieId')

# %%
df_merged=df.drop('movieId',axis=1)

# %% [markdown]
# 1.Find out the list of most popular and liked genre
# --------

# %% [markdown]
# Popular - Genre which has been rated most times

# %%
df_merged.describe(include='object')
# Out:
#          Cust_Id                                              title    genres
# count   24053764                                           23813503  23813503
# unique    470758                                               4405        19
# top       305344  Marie from the Bay of Angels (Marie Baie Des A...     Drama
# freq        4467                                             193941   6670725

# %% [markdown]
# Drama is the most popular genre

# %% [markdown]
# Liked genre - rated high

# %%
rate=df_merged.groupby(['genres']).mean(['Rating'])

# %%
rate[rate['Rating']==rate['Rating'].max()]
# Out:
#            Rating     movie_id
# genres
# Musical  3.844063  1818.362647

# %% [markdown]
# 3.Find what Genre Movies have received the best and worst ratings based on User Rating.
# ----

# %%
rate[rate['Rating']==rate['Rating'].max()]
# Out:
#            Rating     movie_id
# genres
# Musical  3.844063  1818.362647

# %%
rate[rate['Rating']==rate['Rating'].min()]
# Out:
#           Rating     movie_id
# genres
# War     3.147445  3352.701411

# %% [markdown]
# 2.Create Model that finds the best suited Movie for one user in every genre
# ---------------

# %%
from surprise import Reader, Dataset, SVD
from surprise.model_selection import cross_validate

# %%
reader=Reader()

data = Dataset.load_from_df(df_merged[['Cust_Id', 'movie_id', 'Rating']][:100000], reader)

svd = SVD()

cross_validate(svd, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0567  1.0491  1.0502  1.0520  0.0034
# MAE (testset)     0.8399  0.8300  0.8279  0.8326  0.0053
# Fit time          2.55    1.92    2.43    2.30    0.27
# Test time         0.68    0.40    0.58    0.55    0.11
# {'test_rmse': array([1.05671578, 1.04910014, 1.05024987]),
#  'test_mae': array([0.83993999, 0.82998365, 0.82786892]),
#  'fit_time': (2.55295991897583, 1.9175710678100586, 2.4285783767700195),
#  'test_time': (0.675938606262207, 0.40250611305236816, 0.5755908489227295)}

# %%
user_712664 = df_title.copy()

# %%
user_712664 = user_712664.reset_index()

# %%
data = Dataset.load_from_df(df_merged[['Cust_Id', 'movie_id', 'Rating']], reader)

# %%
data

# %%
trainset = data.build_full_trainset()

# %%
svd.fit(trainset)

# %%
user_712664['Estimate_Score'] = user_712664['movieId'].apply(lambda x: svd.predict(712664, x).est)

#Drop extra columns from the user_712664 data frame
user_712664 = user_712664.drop('index', axis = 1)

# %%
user_712664
# Out:
#        movieId                               title              genres  \
# 0            1                    Toy Story (1995)           Adventure
# 1            2                      Jumanji (1995)           Adventure
# 2            3             Grumpier Old Men (1995)              Comedy
# 3            4            Waiting to Exhale (1995)              Comedy
# 4            5  Father of the Bride Part II (1995)              Comedy
# ...        ...                                 ...                 ...
# 27273   131254        Kein Bund für's Leben (2007)              Comedy
# 27274   131256       Feuer, Eis & Dosenbier (2002)              Comedy
# 27275   131258                  The Pirates (2014)           Adventure
# 27276   131260                 Rentun Ruusu (2001)  (no genres listed)
# 27277   131262                    Innocence (2014)           Adventure
#
#        Estimate_Score
# 0            3.871708
# 1            3.779419
# 2            3.783955
# 3            2.868392
# 4            3.956485
# ...               ...
# 27273        3.599634
# 27274        3.599634
# 27275        3.599634
# 27276        3.599634
# 27277        3.599634
#
# [27278 rows x 4 columns]

# %%
user_712664['genres'].nunique()
# Out:
# 20

# %% [markdown]
# List best suited Movie for one user in every genre.
# --------------

# %%
user_712664.groupby('genres').max(['Estimate_Score'])
# Out:
#                     movieId  Estimate_Score
# genres
# (no genres listed)   131260        3.599634
# Action               131180        4.475107
# Adventure            131262        4.477167
# Animation            131243        4.285115
# Children             131054        4.229188
# Comedy               131256        4.498832
# Crime                131011        4.455889
# Documentary          131110        4.245576
# Drama                131176        4.673273
# Fantasy              130071        3.938225
# Film-Noir            122343        3.921899
# Horror               131015        4.437537
# IMAX                   4460        3.368754
# Musical              120588        4.044795
# Mystery              129506        4.014372
# Romance              130588        4.100731
# Sci-Fi               131170        4.074293
# Thriller             131019        4.284860
# War                  131164        3.824743
# Western              129709        4.069224

# %%
user_712664.groupby('genres').agg({'title':'first','Estimate_Score':'max'})
# Out:
#                                                                 title  \
# genres
# (no genres listed)                           Milky Way (Tejút) (2007)
# Action                            Turbo: A Power Rangers Movie (1997)
# Adventure           NeverEnding Story II: The Next Chapter, The (1...
# Animation                                     Steamboat Willie (1928)
# Children                           5,000 Fingers of Dr. T, The (1953)
# Comedy                                              Spaceballs (1987)
# Crime                                       Pelican Brief, The (1993)
# Documentary           Haunted World of Edward D. Wood Jr., The (1996)
# Drama                    Color of Paradise, The (Rang-e khoda) (1999)
# Fantasy                                         Made in Heaven (1987)
# Film-Noir                                       Third Man, The (1949)
# Horror                               Pit and the Pendulum, The (1961)
# IMAX                          Encounter in the Third Dimension (1999)
# Musical                                        Happy Go Lovely (1951)
# Mystery                                        Mortal Thoughts (1991)
# Romance                                  Life Less Ordinary, A (1997)
# Sci-Fi                            Earth vs. the Flying Saucers (1956)
# Thriller                                   Bone Collector, The (1999)
# War                                             Pharaoh's Army (1995)
# Western                                           Hi-Yo Silver (1940)
#
#                     Estimate_Score
# genres
# (no genres listed)        3.599634
# Action                    4.475107
# Adventure                 4.477167
# Animation                 4.285115
# Children                  4.229188
# Comedy                    4.498832
# Crime                     4.455889
# Documentary               4.245576
# Drama                     4.673273
# Fantasy                   3.938225
# Film-Noir                 3.921899
# Horror                    4.437537
# IMAX                      3.368754
# Musical                   4.044795
# Mystery                   4.014372
# Romance                   4.100731
# Sci-Fi                    4.074293
# Thriller                  4.284860
# War                       3.824743
# Western                   4.069224
